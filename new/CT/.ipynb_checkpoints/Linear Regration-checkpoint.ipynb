# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv('/home/codetrade/Downloads/creditcard.csv')

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
import numpy as np
from datetime import datetime
# data['dob'] = pd.to_datetime(data['dob']).astype(np.int64)
x= data.drop(['V1'], axis=1)
y = data['Time']

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x, y)
plt.xlabel('V1 Data')
plt.ylabel('Time Data')
plt.title('Regration')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x1= data.drop(['V1'], axis=1)
y1 = data['Time']

# Generate some random data
x1 = np.random.rand(50)
y1 = np.random.rand(50)
plt.scatter(x, y)
plt.xlabel('V1 V5 V6 V7 V8')
plt.ylabel('Time Data')
plt.title('Regration')
plt.show()
# Change label colo

plt.show()

# %%
data.plot("V1", "Time")
# Out:
# <AxesSubplot:xlabel='V1'>

# %%
data.plot('V5','Time')
# Out:
# <AxesSubplot:xlabel='V5'>

# %%
plt.xlabel("V")
plt.ylabel("V1") 
plt.plot(x1,y1,'r')
plt.plot(x1,y1,'>')

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.plot.scatter("V1", "Amount")
# Out:
# <AxesSubplot:xlabel='V1', ylabel='Amount'>

# %% [markdown]
# ###

# %%
x_train, x_test, y_train, y_test =train_test_split(data.Amount,data.V23, test_size = 0.2)
regr = LinearRegression()
regr.fit(np.array(x_train).reshape(-1,1), y_train)
# Out:
# LinearRegression()

# %%
value = regr.predict(np.array(x_test).reshape(-1,1))

# %%
y_test.head()
# Out:
# 156921   -0.372033
# 176581   -0.114264
# 29935    -0.249017
# 125970    0.086377
# 275559    0.355268
# Name: V23, dtype: float64

# %%
value
# Out:
# array([ 2.11410884e-02,  1.05373265e-03,  5.07724409e-04, ...,
#         1.88157638e-02,  9.82182295e-05, -3.88623433e-02])

# %%
residuals = value - y_test

# %%
plt.hist(residuals)
# Out:
# (array([2.0000e+00, 1.0000e+01, 2.4000e+01, 2.9700e+02, 5.6492e+04,
#         1.0600e+02, 2.0000e+01, 8.0000e+00, 2.0000e+00, 1.0000e+00]),
#  array([-22.06849212, -17.11504927, -12.16160642,  -7.20816358,
#          -2.25472073,   2.69872211,   7.65216496,  12.60560781,
#          17.55905065,  22.5124935 ,  27.46593635]),
#  <BarContainer object of 10 artists>)

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
plt.title("Graph Drawing") 
plt.xlabel("Time") 
plt.ylabel("Distance") 
plt.plot(x1,y1)

#Annotate
# plt.annotate(xy=['V1','V2'], s='Second Entry') 
# plt.annotate(xy=[4,6], s='Third Entry') 
# Adding Legends
# plt.plot(x,y)
# plt.plot(x,t)
plt.legend(['view'], loc=4)

# %%
x4= data.drop(['Amount'], axis=1)
y4 = data['V2']

# Generate some random data
x4 = np.random.rand(10)
y4 = np.random.rand(10)
slope, intercept, r, p, std_err = stats.linregress(x4, y4)

def myfunc(x4):
  return slope * x4 + intercept
mymodel = list(map(myfunc, x4))
plt.scatter(x4, y4)
plt.plot(x4, mymodel)
plt.show()

# %%
data.plot.scatter("Amount", "V2")
# Out:
# <AxesSubplot:xlabel='Amount', ylabel='V2'>

# %%
data.plot.scatter("Time", "V1")
# Out:
# <AxesSubplot:xlabel='Time', ylabel='V1'>

# %%
import statistics

student_ages = [9, 10, 9, 10, 9, 9, 10, 11, 11, 10, 9, 9]
median_age = statistics.median(student_ages)
print(median_age)
# Out:
# 9.5

# %%
mean1 = data['Time'].mean()
print('mean time: ' + str(mean1))
# Out:
# mean time: 94813.85957508067

# %%
mean2 = data['V1'].mean()
print('mean V1: ' + str(mean2))
# Out:
# mean V1: 3.918648695036257e-15

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# ...

# %%
data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#distributions of legit transactions & fraud transactions
data['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
normal_transactions=data[data.Class==0]
fraud_transactions=data[data.Class==1]

# %%
print(normal_transactions.shape)
print(fraud_transactions.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
normal_transactions.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud_transactions.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
data.groupby('Class').std()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      47484.015786  1.929814  1.636146  1.459429  1.399333  1.356952
# 1      47835.365138  6.783687  4.291216  7.110937  2.873318  5.372468
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      1.329913  1.178812  1.161283  1.089372  ...  0.769404  0.716743
# 1      1.858124  7.206773  6.797831  2.500896  ...  1.346635  3.869304
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.723668  0.621541  0.605776  0.520673  0.482241  0.399847  0.329570
# 1      1.494602  1.579642  0.515577  0.797205  0.471679  1.376766  0.547291
#
#            Amount
# Class
# 0      250.105092
# 1      256.683288
#
# [2 rows x 30 columns]

# %%
normal_transactions_sample=normal_transactions.sample(n=492)

# %%
new_data=pd.concat([normal_transactions_sample,fraud_transactions],axis=0)

# %%
new_data.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 77964    57303.0  1.031550 -0.148250  1.232180  1.320165 -0.765565  0.296240
# 237103  149094.0  1.428725 -1.093690 -0.623328  1.369187 -0.738150  0.013940
# 19449    30294.0  1.295643  0.596228 -0.727354  1.168569  0.362060 -0.798894
# 29446    35474.0  1.341635 -0.546208 -1.837083 -2.440676  1.932367  2.751909
# 179801  124245.0  2.090307 -0.828806 -1.391254 -0.621484 -0.432504 -0.493301
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 77964  -0.526489  0.170075  0.757232  ... -0.000420  0.189032 -0.021008
# 237103 -0.297000  0.087326  0.784949  ...  0.403621  0.641967 -0.134141
# 19449   0.194113 -0.107927  0.189943  ... -0.139884 -0.397415 -0.209649
# 29446  -0.330069  0.627234  1.137919  ... -0.079679 -0.192045 -0.226396
# 179801 -0.475272 -0.083898 -0.719238  ... -0.078336  0.182449  0.149688
#
# ...

# %%
new_data.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
new_data['Class'].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
new_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94625.225610 -0.121797 -0.156639  0.033111 -0.017600  0.053226
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.154381  0.039372  0.054860 -0.048589  ...  0.006441 -0.023447
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.049402 -0.011590  0.012005  0.028091  0.009311 -0.006422  0.012635
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.969065
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
X=new_data.drop(columns='Class', axis=1)
Y=new_data['Class']

# %%
print(X)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 77964    57303.0  1.031550 -0.148250  1.232180  1.320165 -0.765565  0.296240
# 237103  149094.0  1.428725 -1.093690 -0.623328  1.369187 -0.738150  0.013940
# 19449    30294.0  1.295643  0.596228 -0.727354  1.168569  0.362060 -0.798894
# 29446    35474.0  1.341635 -0.546208 -1.837083 -2.440676  1.932367  2.751909
# 179801  124245.0  2.090307 -0.828806 -1.391254 -0.621484 -0.432504 -0.493301
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
print(Y)
# Out:
# 77964     0
# 237103    0
# 19449     0
# 29446     0
# 179801    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=2)

# %%
print(X.shape, X_train.shape,X_test.shape )
# Out:
# (984, 30) (787, 30) (197, 30)

# %%
## Logistics Regression
model1= LogisticRegression()

# %%
model1.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
X_train_prediction=model1.predict(X_train)
training_data_accuracy= accuracy_score(X_train_prediction,Y_train)

# %%
print('Accuracy of the Training data :' ,training_data_accuracy)
# Out:
# Accuracy of the Training data : 0.9377382465057179

# %%
X_test_prediction=model1.predict(X_test)
test_data_accuracy= accuracy_score(X_test_prediction,Y_test)

# %%
print('Accuracy of the Test data :' ,test_data_accuracy)
# Out:
# Accuracy of the Test data : 0.9441624365482234
